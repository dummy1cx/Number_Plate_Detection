# %% [markdown]
# ## Model testing
# ## Inference

# %% [markdown]
# ###### Test 1 .jpg image with unseen image

# %%
import cv2
import matplotlib.pyplot
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/abhishekdas/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO

# Load the best.pt
model = YOLO("/content/best.pt")

results = model.predict('/content/car.jpg', device='cpu')


result = results[0]


image_with_boxes = result.plot()  #  (BGR format)

# Convert from BGR to RGB (opencv to matplotlib format)
image_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the images

plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Predicted Bounding Box")
plt.show()
# Out:
# image 1/1 /content/car.jpg: 416x640 1 number_plate, 138.2ms
# Speed: 4.1ms preprocess, 138.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)

# %% [markdown]
# ##Test 2 with multiple text fonts

# %%
## Testing with multiple text fonts

results = model.predict('/content/car1.jpg', device='cpu')


result = results[0]


image_with_boxes = result.plot()  #  (BGR format)

# Convert from BGR to RGB (opencv to matplotlib format)
image_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the images

plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Predicted Bounding Box")
plt.show()
# Out:
# image 1/1 /content/car1.jpg: 448x640 2 number_plates, 152.0ms
# Speed: 5.3ms preprocess, 152.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# ### Test 3 blurry number plate

# %%
# Testing with blurry number plates

results = model.predict('/content/Cars142.png', device='cpu')


result = results[0]


image_with_boxes = result.plot()  #  (BGR format)

# Convert from BGR to RGB (opencv to matplotlib format)
image_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the images

plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Predicted Bounding Box")
plt.show()
# Out:
# image 1/1 /content/Cars142.png: 320x640 1 number_plate, 106.2ms
# Speed: 2.3ms preprocess, 106.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)

# %% [markdown]
# ##Test 4 no number_plate class

# %%
 ## Testing without any number plate

 # Testing with blurry number plates

results = model.predict('/content/animal.webp', device='cpu')


result = results[0]


image_with_boxes = result.plot()  #  (BGR format)

# Convert from BGR to RGB (opencv to matplotlib format)
image_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the images

plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Predicted Bounding Box")
plt.show()
# Out:
# image 1/1 /content/animal.webp: 480x640 (no detections), 270.7ms
# Speed: 6.9ms preprocess, 270.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ## test 5 detection in traffic

# %%
 ## Testing without any number plate

 # Testing with blurry number plates

results = model.predict('/content/traffic.jpg', device='cpu')


result = results[0]


image_with_boxes = result.plot()  #  (BGR format)

# Convert from BGR to RGB (opencv to matplotlib format)
image_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the images

plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Predicted Bounding Box")
plt.show()
# Out:
# image 1/1 /content/traffic.jpg: 352x640 3 number_plates, 126.6ms
# Speed: 2.8ms preprocess, 126.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
